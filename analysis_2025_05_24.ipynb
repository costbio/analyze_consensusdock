# %%
import os
import pandas as pd
import re

base_dir = os.getcwd()  # or set to your base path if not running from cwd

all_results = []

for uniprot in os.listdir(base_dir):
    uniprot_path = os.path.join(base_dir, uniprot)
    if os.path.isdir(uniprot_path):
        for subfolder in os.listdir(uniprot_path):
            match = re.match(r'dock(\d+)_(\w+)', subfolder)
            if match:
                pocket_number, ligcode = match.groups()
                result_file = os.path.join(uniprot_path, subfolder, 'final_results.csv')
                if os.path.isfile(result_file):
                    df = pd.read_csv(result_file)
                    df['uniprot'] = uniprot
                    df['pocket_number'] = pocket_number
                    df['ligcode'] = ligcode
                    all_results.append(df)

# Concatenate all dataframes
final_df = pd.concat(all_results, ignore_index=True)

# Optionally, save to a CSV
#final_df.to_csv('all_final_results.csv', index=False)
# Out:
#     Tool1 Tool2  PoseNumber1  PoseNumber2  Score1  Score2          File1  \
# 0  LeDock  GOLD            6            2   -2.43   31.45  complex_6.pdb
# 1  LeDock  GOLD            6            1   -2.43   31.31  complex_6.pdb
# 2  LeDock  GOLD            6            3   -2.43   31.66  complex_6.pdb
# 3  LeDock  GOLD            2            2   -2.94   31.45  complex_2.pdb
# 4  LeDock  GOLD            2            1   -2.94   31.31  complex_2.pdb
#
#            File2      RMSD uniprot pocket_number ligcode
# 0  complex_2.pdb  7.121884  P03372             4     EZT
# 1  complex_1.pdb  7.110847  P03372             4     EZT
# 2  complex_3.pdb  7.099406  P03372             4     EZT
# 3  complex_2.pdb  7.161547  P03372             4     EZT
# 4  complex_1.pdb  7.155044  P03372             4     EZT

# %%
final_df['uniprot_ligcode']= final_df['uniprot'] + '_' + final_df['ligcode']
final_df.head()
# Out:
#     Tool1 Tool2  PoseNumber1  PoseNumber2  Score1  Score2          File1  \
# 0  LeDock  GOLD            6            2   -2.43   31.45  complex_6.pdb
# 1  LeDock  GOLD            6            1   -2.43   31.31  complex_6.pdb
# 2  LeDock  GOLD            6            3   -2.43   31.66  complex_6.pdb
# 3  LeDock  GOLD            2            2   -2.94   31.45  complex_2.pdb
# 4  LeDock  GOLD            2            1   -2.94   31.31  complex_2.pdb
#
#            File2      RMSD uniprot pocket_number ligcode uniprot_ligcode
# 0  complex_2.pdb  7.121884  P03372             4     EZT      P03372_EZT
# 1  complex_1.pdb  7.110847  P03372             4     EZT      P03372_EZT
# 2  complex_3.pdb  7.099406  P03372             4     EZT      P03372_EZT
# 3  complex_2.pdb  7.161547  P03372             4     EZT      P03372_EZT
# 4  complex_1.pdb  7.155044  P03372             4     EZT      P03372_EZT

# %%
# For each unique uniprot_ligcode, how many rows showed an RMSD value lower than 2.0?
rmsd_counts = final_df[final_df['RMSD'] < 2.0].groupby('uniprot_ligcode').size().reset_index(name='count')

# %%
# For each unique uniprot_ligcode, how many rows are between PoseNumber1 = 1 and PoseNumber2 = 1 and showed an RMSD value lower than 2.0?
pose_counts = final_df[(final_df['PoseNumber1'] == 1) & (final_df['PoseNumber2'] == 1) & (final_df['RMSD'] < 2.0)].groupby('uniprot_ligcode').size().reset_index(name='count')

# %%
# For each unique uniprot_ligcode, how many of them showed an RMSD value lower than 2.0 with at least three different Tool1 and Tool2 combinations?
tool_counts = final_df[final_df['RMSD'] < 2.0].groupby('uniprot_ligcode').apply(lambda x: x[['Tool1', 'Tool2']].drop_duplicates().shape[0]).reset_index(name='unique_tool_combinations')

# %%
tool_counts
# Out:
#    uniprot_ligcode  unique_tool_combinations
# 0       O14757_agy                         1
# 1       O14757_ucn                         3
# 2       O14965_0c8                         1
# 3       O14965_eml                         1
# 4       O14965_vx6                         1
# 5       O60674_0nv                         3
# 6       O60674_1k3                         1
# 7       O60674_jak                         1
# 8       P00519_3yy                         1
# 9       P00519_627                         1
# 10      P00734_32u                         1
# 11      P00749_239                         1
# 12      P00749_ui1                         1
# 13      P03372_EST                         3
# 14      P03372_EZT                         3
# 15      P03372_JJ3                         1
# 16      P03372_WST                         3
# 17      P07900_4BC                         1
# 18      P11309_1OB                         1
# 19      P11309_1YZ                         1
# 20      P11309_5H7                         1
# 21      P11309_IYZ                         1
# 22      P11309_VX3                         1
# 23      P23458_0NT                         1
# 24      P23458_15T                         1
# 25      P23458_1J5                         1
# 26      P23458_1J6                         1
# 27      P23458_1Q4                         3
# 28      P24941_4SP                         1
# 29      P24941_CK6                         1
# 30      P24941_LIA                         1
# 31      P37231_KRC                         1
# 32      P37231_YFE                         1
# 33      P39086_NDZ                         1
# 34      P39900_NHK                         1
# 35      P56817_0KM                         3
# 36      Q08881_L7O                         1
# 37      Q16539_19B                         1
# 38      Q16539_LM4                         1
# 39      Q9H2K2_DFL                         3
# 40      Q9H2K2_XAV                         1
# 41      Q9Y233_0CV                         1
# 42      Q9Y233_C1L                         1

# %%
len(final_df['uniprot_ligcode'].unique())
# Out:
# 57

# %%
final_df.query('uniprot_ligcode == "O14757_ucn" & RMSD < 2.0').sort_values('RMSD')
# Out:
#         Tool1  Tool2  PoseNumber1  PoseNumber2  Score1    Score2  \
# 95816  LeDock   GOLD            9            9   -4.87  45.59000
# 95817  LeDock   GOLD            9            4   -4.87  45.21000
# 95804  LeDock   GOLD            9           16   -4.87  45.10000
# 95803  LeDock   GOLD            9           20   -4.87  45.50000
# 96805  LeDock   GOLD            1            8   -5.97  60.65000
# 93839  LeDock   GOLD            3           11   -4.92  57.49000
# 96473  LeDock   GOLD            2            2   -5.47  54.56000
# 93855  LeDock   GOLD            3           12   -4.92  56.11000
# 93844  LeDock   GOLD            3           16   -4.92  56.55000
# 96475  LeDock   GOLD            2            3   -5.47  54.54000
# 93863  LeDock   GOLD            5           20   -4.78  60.22000
# 93876  LeDock   GOLD            5            9   -4.78  60.21000
# 93877  LeDock   GOLD            5            4   -4.78  60.56000
# 93867  LeDock   GOLD            5            2   -4.78  60.25000
# 93874  LeDock   GOLD            5            5   -4.78  60.47000
# 94165    GOLD  Smina           14           14   62.69  -7.42079
# 95846  LeDock  Smina            7           10   -4.92  -7.96291
# 94025    GOLD  Smina            7           14   61.19  -7.42079
# 97043    GOLD  Smina           14            7   56.50  -8.53935
# 96954    GOLD  Smina            8            1   60.65 -10.22287
# 96915    GOLD  Smina            7            3   71.44  -9.53434
# 96862  LeDock  Smina            2            4   -5.53  -9.27729
# 93901  LeDock  Smina            6            6   -4.71  -8.38284
# 88437  LeDock  Smina            2            2   -4.82  -8.42120
# 96874  LeDock  Smina            1            1   -5.97 -10.22287
# 97195    GOLD  Smina           17            3   71.54  -9.53434
# 91180  LeDock  Smina            2            8   -4.59  -6.82536
# 96011  LeDock  Smina            5           18   -4.96  -7.55879
# 96201    GOLD  Smina           14            6   46.56  -8.15444
# 95897  LeDock  Smina            8            4   -4.89  -8.45775
# 88451  LeDock  Smina            1            6   -5.23  -7.66798
# 96886  LeDock  Smina            3            6   -5.42  -8.66792
# 88522  LeDock  Smina            4           17   -4.51  -7.16521
# 93990  LeDock  Smina            5            3   -4.78  -8.58224
# 97063    GOLD  Smina           10            7   61.41  -8.53935
# 88498  LeDock  Smina            5           13   -4.45  -7.24983
# 91165  LeDock  Smina            6           14   -4.48  -6.49421
# 96923    GOLD  Smina           11            7   61.70  -8.53935
#
#                 File1           File2      RMSD uniprot pocket_number ligcode  \
# 95816   complex_9.pdb   complex_9.pdb  0.331356  O14757             3     ucn
# 95817   complex_9.pdb   complex_4.pdb  0.349086  O14757             3     ucn
# 95804   complex_9.pdb  complex_16.pdb  0.364222  O14757             3     ucn
# 95803   complex_9.pdb  complex_20.pdb  0.370975  O14757             3     ucn
# 96805   complex_1.pdb   complex_8.pdb  0.597613  O14757             4     ucn
# 93839   complex_3.pdb  complex_11.pdb  0.725013  O14757             5     ucn
# 96473   complex_2.pdb   complex_2.pdb  0.768561  O14757             1     ucn
# 93855   complex_3.pdb  complex_12.pdb  0.793224  O14757             5     ucn
# 93844   complex_3.pdb  complex_16.pdb  0.796979  O14757             5     ucn
# 96475   complex_2.pdb   complex_3.pdb  0.806143  O14757             1     ucn
# 93863   complex_5.pdb  complex_20.pdb  1.012754  O14757             5     ucn
# 93876   complex_5.pdb   complex_9.pdb  1.022164  O14757             5     ucn
# 93877   complex_5.pdb   complex_4.pdb  1.022769  O14757             5     ucn
# 93867   complex_5.pdb   complex_2.pdb  1.029252  O14757             5     ucn
# 93874   complex_5.pdb   complex_5.pdb  1.036297  O14757             5     ucn
# 94165  complex_14.pdb  complex_14.pdb  1.346667  O14757             5     ucn
# 95846   complex_7.pdb  complex_10.pdb  1.435051  O14757             3     ucn
# 94025   complex_7.pdb  complex_14.pdb  1.442662  O14757             5     ucn
# 97043  complex_14.pdb   complex_7.pdb  1.503357  O14757             4     ucn
# 96954   complex_8.pdb   complex_1.pdb  1.508518  O14757             4     ucn
# 96915   complex_7.pdb   complex_3.pdb  1.527049  O14757             4     ucn
# 96862   complex_2.pdb   complex_4.pdb  1.535191  O14757             4     ucn
# 93901   complex_6.pdb   complex_6.pdb  1.545372  O14757             5     ucn
# 88437   complex_2.pdb   complex_2.pdb  1.555491  O14757             2     ucn
# 96874   complex_1.pdb   complex_1.pdb  1.556011  O14757             4     ucn
# 97195  complex_17.pdb   complex_3.pdb  1.556600  O14757             4     ucn
# 91180   complex_2.pdb   complex_8.pdb  1.572624  O14757             6     ucn
# 96011   complex_5.pdb  complex_18.pdb  1.590326  O14757             3     ucn
# 96201  complex_14.pdb   complex_6.pdb  1.593743  O14757             3     ucn
# 95897   complex_8.pdb   complex_4.pdb  1.596179  O14757             3     ucn
# 88451   complex_1.pdb   complex_6.pdb  1.653075  O14757             2     ucn
# 96886   complex_3.pdb   complex_6.pdb  1.680989  O14757             4     ucn
# 88522   complex_4.pdb  complex_17.pdb  1.732527  O14757             2     ucn
# 93990   complex_5.pdb   complex_3.pdb  1.764094  O14757             5     ucn
# 97063  complex_10.pdb   complex_7.pdb  1.831891  O14757             4     ucn
# 88498   complex_5.pdb  complex_13.pdb  1.912310  O14757             2     ucn
# 91165   complex_6.pdb  complex_14.pdb  1.929044  O14757             6     ucn
# 96923  complex_11.pdb   complex_7.pdb  1.948864  O14757             4     ucn
#
#       uniprot_ligcode
# 95816      O14757_ucn
# 95817      O14757_ucn
# 95804      O14757_ucn
# 95803      O14757_ucn
# 96805      O14757_ucn
# 93839      O14757_ucn
# 96473      O14757_ucn
# 93855      O14757_ucn
# 93844      O14757_ucn
# 96475      O14757_ucn
# 93863      O14757_ucn
# 93876      O14757_ucn
# 93877      O14757_ucn
# 93867      O14757_ucn
# 93874      O14757_ucn
# 94165      O14757_ucn
# 95846      O14757_ucn
# 94025      O14757_ucn
# 97043      O14757_ucn
# 96954      O14757_ucn
# 96915      O14757_ucn
# 96862      O14757_ucn
# 93901      O14757_ucn
# 88437      O14757_ucn
# 96874      O14757_ucn
# 97195      O14757_ucn
# 91180      O14757_ucn
# 96011      O14757_ucn
# 96201      O14757_ucn
# 95897      O14757_ucn
# 88451      O14757_ucn
# 96886      O14757_ucn
# 88522      O14757_ucn
# 93990      O14757_ucn
# 97063      O14757_ucn
# 88498      O14757_ucn
# 91165      O14757_ucn
# 96923      O14757_ucn
